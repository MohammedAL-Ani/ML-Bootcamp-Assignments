# %% [markdown]
# #Assignment 06: Computer Vision Applications
#
# This Week's assignment is to train semantic segmentation models on the `Satellite buildings` images dataset.
#
# Before starting copy this file and work on your own copy by following the below steps: <br>
# `File > Save Copy in Drive`. Then add your name to the file (e.g., Assignment 06: Computer Vision Applications - Muntadher Alkaabi).
#
#
# **Submission Deadline: Thursday, 2/24/2022 at 3:00 PM**
#
# **Requirements:**
#
# 1. Import all necessary libraries for the semantic segmentation project.
# 2. Download the dataset (the link is provided below).
# 3. Create a function that convert the images path into dataframe(make sure that the images and their masks are matching).
# 4. Make sure to convert the mask into one hot vector.
# 5. Split the dataset into train and test dateset (test dataset should be 10% of the total dataset).
# 6. Create data pipeline with data augmentation.
#     1. Read images using tensorflow.
#     2. Make sure the pixels values are scaled between (`0-1`).
#     3. Resize the images to (224,224).
#     4. Apply multiple image augmentation on the data (make sure that the image augmentation is reflected on its mask).
#     5. Make sure the augmentation image pixels are scaled between (`0-1`).
# 7. Plot the images.
# 8. Build Autoencoder model.
#
# 9. Build UNet model.<br>
# **Note:** use sub-class to create the model.
#
#
# 10. Plot the model results.
#
#
# **Note:** To get the best performance from the model, manually tune the hyperparameters of each model.
#
# Find relevant links below:<br>
#
# [Assigment Colab File](https://colab.research.google.com/drive/1eoR4qjszwxieYTqPu2da8-kpOKtb0hod?usp=sharing)<br>
# [Dataset](https://www.kaggle.com/hyyyrwang/buildings-dataset)
#
# [Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSfzW6FI2urJ-zlAV8sS9brv4cbpe6npmQg5KuD83nifeUgwHw/viewform?usp=pp_url)<br>
# [How to use kaggle with colab](https://www.analyticsvidhya.com/blog/2021/06/how-to-load-kaggle-datasets-directly-into-google-colab/)<br>
#
#
# Good luck and feel free to ask any questions in the or on the Questions channel.

# %% [markdown]
# # 1- Import all necessary libraries for the semantic segmentation project

# %%
# write your code below

import tensorflow as tf
import numpy as np
import pandas as pd
import glob
from sklearn import model_selection
import matplotlib.pyplot as plt
import tqdm
import os

# %% [markdown]
# # 2- Download the dataset

# %%
# download the required dataset from kaggle 

! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# write your code below

! kaggle datasets download -d hyyyrwang/buildings-dataset
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Downloading buildings-dataset.zip to /content
#  99% 833M/842M [00:14<00:00, 87.8MB/s]
# 100% 842M/842M [00:14<00:00, 59.3MB/s]

# %%
! unzip "/content/buildings-dataset.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: src/T1886.png
#   inflating: src/T1887.png
#   inflating: src/T1888.png
#   inflating: src/T1889.png
#   inflating: src/T189.png
#   inflating: src/T1890.png
#   inflating: src/T1891.png
#   inflating: src/T1892.png
#   inflating: src/T1893.png
#   inflating: src/T1894.png
#   inflating: src/T1895.png
#   inflating: src/T1896.png
#   inflating: src/T1897.png
#   inflating: src/T1898.png
#   inflating: src/T1899.png
#   inflating: src/T19.png
#   inflating: src/T190.png
#   inflating: src/T1900.png
#   inflating: src/T1901.png
#   inflating: src/T1902.png
#   inflating: src/T1903.png
#   inflating: src/T1904.png
#   inflating: src/T1905.png
#   inflating: src/T1906.png
#   inflating: src/T1907.png
#   inflating: src/T1908.png
#   inflating: src/T1909.png
#   inflating: src/T191.png
#   inflating: src/T1910.png
#   inflating: src/T1911.png
#   inflating: src/T1912.png
#   inflating: src/T1913.png
#   inflating: src/T1914.png
#   inflating: src/T1915.png
#   inflating: src/T1916.png
#   inflating: src/T1917.png
#   inflating: src/T1918.png
#   inflating: src/T1919.png
#   inflating: src/T192.png
#   inflating: src/T1920.png
#   inflating: src/T1921.png
#   inflating: src/T1922.png
#   inflating: src/T1923.png
#   inflating: src/T1924.png
#   inflating: src/T1925.png
#   inflating: src/T1926.png
#   inflating: src/T1927.png
#   inflating: src/T1928.png
#   inflating: src/T1929.png
#   inflating: src/T193.png
#   inflating: src/T1930.png
#   inflating: src/T1931.png
#   inflating: src/T1932.png
#   inflating: src/T1933.png
#   inflating: src/T1934.png
#   inflating: src/T1935.png
#   inflating: src/T1936.png
#   inflating: src/T1937.png
#   inflating: src/T1938.png
#   inflating: src/T1939.png
#   inflating: src/T194.png
#   inflating: src/T1940.png
#   inflating: src/T1941.png
#   inflating: src/T1942.png
#   inflating: src/T1943.png
#   inflating: src/T1944.png
#   inflating: src/T1945.png
#   inflating: src/T1946.png
#   inflating: src/T1947.png
#   inflating: src/T1948.png
#   inflating: src/T1949.png
#   inflating: src/T195.png
#   inflating: src/T1950.png
#   inflating: src/T1951.png
#   inflating: src/T1952.png
#   inflating: src/T1953.png
#   inflating: src/T1954.png
#   inflating: src/T1955.png
#   inflating: src/T1956.png
#   inflating: src/T1957.png
#   inflating: src/T1958.png
#   inflating: src/T1959.png
#   inflating: src/T196.png
#   inflating: src/T1960.png
#   inflating: src/T1961.png
#   inflating: src/T1962.png
#   inflating: src/T1963.png
#   inflating: src/T1964.png
#   inflating: src/T1965.png
#   inflating: src/T1966.png
#   inflating: src/T1967.png
#   inflating: src/T1968.png
#   inflating: src/T1969.png
#   inflating: src/T197.png
#   inflating: src/T1970.png
#   inflating: src/T1971.png
#   inflating: src/T1972.png
#   inflating: src/T1973.png
#   inflating: src/T1974.png
#   inflating: src/T1975.png
#   inflating: src/T1976.png
#   inflating: src/T1977.png
#   inflating: src/T1978.png
#   inflating: src/T1979.png
#   inflating: src/T198.png
#   inflating: src/T1980.png
#   inflating: src/T1981.png
#   inflating: src/T1982.png
#   inflating: src/T1983.png
#   inflating: src/T1984.png
#   inflating: src/T1985.png
#   inflating: src/T1986.png
#   inflating: src/T1987.png
#   inflating: src/T1988.png
#   inflating: src/T1989.png
#   inflating: src/T199.png
#   inflating: src/T1990.png
#   inflating: src/T1991.png
#   inflating: src/T1992.png
#   inflating: src/T1993.png
#   inflating: src/T1994.png
#   inflating: src/T1995.png
#   inflating: src/T1996.png
#   inflating: src/T1997.png
#   inflating: src/T1998.png
#   inflating: src/T1999.png
#   inflating: src/T2.png
#   inflating: src/T20.png
#   inflating: src/T200.png
#   inflating: src/T2000.png
#   inflating: src/T2001.png
#   inflating: src/T2002.png
#   inflating: src/T2003.png
#   inflating: src/T2004.png
#   inflating: src/T2005.png
#   inflating: src/T2006.png
#   inflating: src/T2007.png
#   inflating: src/T2008.png
#   inflating: src/T2009.png
#   inflating: src/T201.png
#   inflating: src/T2010.png
#   inflating: src/T2011.png
#   inflating: src/T2012.png
#   inflating: src/T2013.png
#   inflating: src/T2014.png
#   inflating: src/T2015.png
#   inflating: src/T2016.png
#   inflating: src/T2017.png
#   inflating: src/T2018.png
#   inflating: src/T2019.png
#   inflating: src/T202.png
#   inflating: src/T2020.png
#   inflating: src/T2021.png
#   inflating: src/T2022.png
#   inflating: src/T2023.png
#   inflating: src/T2024.png
#   inflating: src/T2025.png
#   inflating: src/T2026.png
#   inflating: src/T2027.png
#   inflating: src/T2028.png
#   inflating: src/T2029.png
#   inflating: src/T203.png
#   inflating: src/T2030.png
#   inflating: src/T2031.png
#   inflating: src/T2032.png
#   inflating: src/T2033.png
#   inflating: src/T2034.png
#   inflating: src/T2035.png
#   inflating: src/T2036.png
#   inflating: src/T2037.png
#   inflating: src/T2038.png
#   inflating: src/T2039.png
#   inflating: src/T204.png
#   inflating: src/T2040.png
#   inflating: src/T2041.png
#   inflating: src/T2042.png
#   inflating: src/T2043.png
#   inflating: src/T2044.png
#   inflating: src/T2045.png
#   inflating: src/T2046.png
#   inflating: src/T2047.png
#   inflating: src/T2048.png
#   inflating: src/T2049.png
#   inflating: src/T205.png
#   inflating: src/T2050.png
#   inflating: src/T2051.png
#   inflating: src/T2052.png
#   inflating: src/T2053.png
#   inflating: src/T2054.png
#   inflating: src/T2055.png
#   inflating: src/T2056.png
#   inflating: src/T2057.png
#   inflating: src/T2058.png
#   inflating: src/T2059.png
#   inflating: src/T206.png
#   inflating: src/T2060.png
#   inflating: src/T2061.png
#   inflating: src/T2062.png
#   inflating: src/T2063.png
#   inflating: src/T2064.png
#   inflating: src/T2065.png
#   inflating: src/T2066.png
#   inflating: src/T2067.png
#   inflating: src/T2068.png
#   inflating: src/T2069.png
#   inflating: src/T207.png
#   inflating: src/T2070.png
#   inflating: src/T2071.png
#   inflating: src/T2072.png
#   inflating: src/T2073.png
#   inflating: src/T2074.png
#   inflating: src/T2075.png
#   inflating: src/T2076.png
#   inflating: src/T2077.png
#   inflating: src/T2078.png
#   inflating: src/T2079.png
#   inflating: src/T208.png
#   inflating: src/T2080.png
#   inflating: src/T2081.png
#   inflating: src/T2082.png
#   inflating: src/T2083.png
#   inflating: src/T2084.png
#   inflating: src/T2085.png
#   inflating: src/T2086.png
#   inflating: src/T2087.png
#   inflating: src/T2088.png
#   inflating: src/T2089.png
#   inflating: src/T209.png
#   inflating: src/T2090.png
#   inflating: src/T2091.png
#   inflating: src/T2092.png
#   inflating: src/T2093.png
#   inflating: src/T2094.png
#   inflating: src/T2095.png
#   inflating: src/T2096.png
#   inflating: src/T2097.png
#   inflating: src/T2098.png
#   inflating: src/T2099.png
#   inflating: src/T21.png
#   inflating: src/T210.png
#   inflating: src/T2100.png
#   inflating: src/T2101.png
#   inflating: src/T2102.png
#   inflating: src/T2103.png
#   inflating: src/T2104.png
#   inflating: src/T2105.png
#   inflating: src/T2106.png
#   inflating: src/T2107.png
#   inflating: src/T2108.png
#   inflating: src/T2109.png
#   inflating: src/T211.png
#   inflating: src/T2110.png
#   inflating: src/T2111.png
#   inflating: src/T2112.png
#   inflating: src/T2113.png
#   inflating: src/T2114.png
#   inflating: src/T2115.png
#   inflating: src/T2116.png
#   inflating: src/T2117.png
#   inflating: src/T2118.png
#   inflating: src/T2119.png
#   inflating: src/T212.png
#   inflating: src/T2120.png
#   inflating: src/T2121.png
#   inflating: src/T2122.png
#   inflating: src/T2123.png
#   inflating: src/T2124.png
#   inflating: src/T2125.png
#   inflating: src/T2126.png
#   inflating: src/T2127.png
#   inflating: src/T2128.png
#   inflating: src/T2129.png
#   inflating: src/T213.png
#   inflating: src/T2130.png
#   inflating: src/T2131.png
#   inflating: src/T2132.png
#   inflating: src/T2133.png
#   inflating: src/T2134.png
#   inflating: src/T2135.png
#   inflating: src/T2136.png
#   inflating: src/T2137.png
#   inflating: src/T2138.png
#   inflating: src/T2139.png
#   inflating: src/T214.png
#   inflating: src/T2140.png
#   inflating: src/T2141.png
#   inflating: src/T2142.png
#   inflating: src/T2143.png
#   inflating: src/T2144.png
#   inflating: src/T2145.png
#   inflating: src/T2146.png
#   inflating: src/T2147.png
#   inflating: src/T2148.png
#   inflating: src/T2149.png
#   inflating: src/T215.png
#   inflating: src/T2150.png
#   inflating: src/T2151.png
#   inflating: src/T2152.png
#   inflating: src/T2153.png
#   inflating: src/T2154.png
#   inflating: src/T2155.png
#   inflating: src/T2156.png
#   inflating: src/T2157.png
#   inflating: src/T2158.png
#   inflating: src/T2159.png
#   inflating: src/T216.png
#   inflating: src/T2160.png
#   inflating: src/T2161.png
#   inflating: src/T2162.png
#   inflating: src/T2163.png
#   inflating: src/T2164.png
#   inflating: src/T2165.png
#   inflating: src/T2166.png
#   inflating: src/T2167.png
#   inflating: src/T2168.png
#   inflating: src/T2169.png
#   inflating: src/T217.png
#   inflating: src/T2170.png
#   inflating: src/T2171.png
#   inflating: src/T2172.png
#   inflating: src/T2173.png
#   inflating: src/T2174.png
#   inflating: src/T2175.png
#   inflating: src/T2176.png
#   inflating: src/T2177.png
#   inflating: src/T2178.png
#   inflating: src/T2179.png
#   inflating: src/T218.png
#   inflating: src/T2180.png
#   inflating: src/T2181.png
#   inflating: src/T2182.png
#   inflating: src/T2183.png
#   inflating: src/T2184.png
#   inflating: src/T2185.png
#   inflating: src/T2186.png
#   inflating: src/T2187.png
#   inflating: src/T2188.png
#   inflating: src/T2189.png
#   inflating: src/T219.png
#   inflating: src/T2190.png
#   inflating: src/T2191.png
#   inflating: src/T2192.png
#   inflating: src/T2193.png
#   inflating: src/T2194.png
#   inflating: src/T2195.png
#   inflating: src/T2196.png
#   inflating: src/T2197.png
#   inflating: src/T2198.png
#   inflating: src/T2199.png
#   inflating: src/T22.png
#   inflating: src/T220.png
#   inflating: src/T2200.png
#   inflating: src/T2201.png
#   inflating: src/T2202.png
#   inflating: src/T2203.png
#   inflating: src/T2204.png
#   inflating: src/T2205.png
#   inflating: src/T2206.png
#   inflating: src/T2207.png
#   inflating: src/T2208.png
#   inflating: src/T2209.png
#   inflating: src/T221.png
#   inflating: src/T2210.png
#   inflating: src/T2211.png
#   inflating: src/T2212.png
#   inflating: src/T2213.png
#   inflating: src/T2214.png
#   inflating: src/T2215.png
#   inflating: src/T2216.png
#   inflating: src/T2217.png
#   inflating: src/T2218.png
#   inflating: src/T2219.png
#   inflating: src/T222.png
#   inflating: src/T2220.png
#   inflating: src/T2221.png
#   inflating: src/T2222.png
#   inflating: src/T2223.png
#   inflating: src/T2224.png
#   inflating: src/T2225.png
#   inflating: src/T2226.png
#   inflating: src/T2227.png
#   inflating: src/T2228.png
#   inflating: src/T2229.png
#   inflating: src/T223.png
#   inflating: src/T2230.png
#   inflating: src/T2231.png
#   inflating: src/T2232.png
#   inflating: src/T2233.png
#   inflating: src/T2234.png
#   inflating: src/T2235.png
#   inflating: src/T2236.png
#   inflating: src/T2237.png
#   inflating: src/T2238.png
#   inflating: src/T2239.png
#   inflating: src/T224.png
#   inflating: src/T2240.png
#   inflating: src/T2241.png
#   inflating: src/T2242.png
#   inflating: src/T2243.png
#   inflating: src/T2244.png
#   inflating: src/T2245.png
#   inflating: src/T2246.png
#   inflating: src/T2247.png
#   inflating: src/T2248.png
#   inflating: src/T2249.png
#   inflating: src/T225.png
#   inflating: src/T2250.png
#   inflating: src/T2251.png
#   inflating: src/T2252.png
#   inflating: src/T2253.png
#   inflating: src/T2254.png
#   inflating: src/T2255.png
#   inflating: src/T2256.png
#   inflating: src/T2257.png
#   inflating: src/T2258.png
#   inflating: src/T2259.png
#   inflating: src/T226.png
#   inflating: src/T2260.png
#   inflating: src/T2261.png
#   inflating: src/T2262.png
#   inflating: src/T2263.png
#   inflating: src/T2264.png
#   inflating: src/T2265.png
#   inflating: src/T2266.png
#   inflating: src/T2267.png
#   inflating: src/T2268.png
#   inflating: src/T2269.png
#   inflating: src/T227.png
#   inflating: src/T2270.png
#   inflating: src/T2271.png
#   inflating: src/T2272.png
#   inflating: src/T2273.png
#   inflating: src/T2274.png
#   inflating: src/T2275.png
#   inflating: src/T2276.png
#   inflating: src/T2277.png
#   inflating: src/T2278.png
#   inflating: src/T2279.png
#   inflating: src/T228.png
#   inflating: src/T2280.png
#   inflating: src/T2281.png
#   inflating: src/T2282.png
#   inflating: src/T2283.png
#   inflating: src/T2284.png
#   inflating: src/T2285.png
#   inflating: src/T2286.png
#   inflating: src/T2287.png
#   inflating: src/T2288.png
#   inflating: src/T2289.png
#   inflating: src/T229.png
#   inflating: src/T2290.png
#   inflating: src/T2291.png
#   inflating: src/T2292.png
#   inflating: src/T2293.png
#   inflating: src/T2294.png
#   inflating: src/T2295.png
#   inflating: src/T2296.png
#   inflating: src/T2297.png
#   inflating: src/T2298.png
#   inflating: src/T2299.png
#   inflating: src/T23.png
#   inflating: src/T230.png
#   inflating: src/T2300.png
#   inflating: src/T2301.png
#   inflating: src/T2302.png
#   inflating: src/T2303.png
#   inflating: src/T2304.png
#   inflating: src/T2305.png
#   inflating: src/T2306.png
#   inflating: src/T2307.png
#   inflating: src/T2308.png
#   inflating: src/T2309.png
#   inflating: src/T231.png
#   inflating: src/T2310.png
#   inflating: src/T2311.png
#   inflating: src/T2312.png
#   inflating: src/T2313.png
#   inflating: src/T2314.png
#   inflating: src/T2315.png
#   inflating: src/T2316.png
#   inflating: src/T2317.png
#   inflating: src/T2318.png
#   inflating: src/T2319.png
#   inflating: src/T232.png
#   inflating: src/T2320.png
#   inflating: src/T2321.png
#   inflating: src/T2322.png
#   inflating: src/T2323.png
#   inflating: src/T2324.png
#   inflating: src/T2325.png
#   inflating: src/T2326.png
#   inflating: src/T2327.png
#   inflating: src/T2328.png
#   inflating: src/T2329.png
#   inflating: src/T233.png
#   inflating: src/T2330.png
#   inflating: src/T2331.png
#   inflating: src/T2332.png
#   inflating: src/T2333.png
#   inflating: src/T2334.png
#   inflating: src/T2335.png
#   inflating: src/T2336.png
#   inflating: src/T2337.png
#   inflating: src/T2338.png
#   inflating: src/T2339.png
#   inflating: src/T234.png
#   inflating: src/T2340.png
#   inflating: src/T2341.png
#   inflating: src/T2342.png
#   inflating: src/T2343.png
#   inflating: src/T2344.png
#   inflating: src/T2345.png
#   inflating: src/T2346.png
#   inflating: src/T2347.png
#   inflating: src/T2348.png
#   inflating: src/T2349.png
#   inflating: src/T235.png
#   inflating: src/T2350.png
#   inflating: src/T2351.png
#   inflating: src/T2352.png
#   inflating: src/T2353.png
#   inflating: src/T2354.png
#   inflating: src/T2355.png
#   inflating: src/T2356.png
#   inflating: src/T2357.png
#   inflating: src/T2358.png
#   inflating: src/T2359.png
#   inflating: src/T236.png
#   inflating: src/T2360.png
#   inflating: src/T2361.png
#   inflating: src/T2362.png
#   inflating: src/T2363.png
#   inflating: src/T2364.png
#   inflating: src/T2365.png
#   inflating: src/T2366.png
#   inflating: src/T2367.png
#   inflating: src/T2368.png
#   inflating: src/T2369.png
#   inflating: src/T237.png
#   inflating: src/T2370.png
#   inflating: src/T2371.png
#   inflating: src/T2372.png
#   inflating: src/T2373.png
#   inflating: src/T2374.png
#   inflating: src/T2375.png
#   inflating: src/T2376.png
#   inflating: src/T2377.png
#   inflating: src/T2378.png
#   inflating: src/T2379.png
#   inflating: src/T238.png
#   inflating: src/T2380.png
#   inflating: src/T2381.png
#   inflating: src/T2382.png
#   inflating: src/T2383.png
#   inflating: src/T2384.png
#   inflating: src/T2385.png
#   inflating: src/T2386.png
#   inflating: src/T2387.png
#   inflating: src/T2388.png
#   inflating: src/T2389.png
#   inflating: src/T239.png
#   inflating: src/T2390.png
#   inflating: src/T2391.png
#   inflating: src/T2392.png
#   inflating: src/T2393.png
#   inflating: src/T2394.png
#   inflating: src/T2395.png
#   inflating: src/T2396.png
#   inflating: src/T2397.png
#   inflating: src/T2398.png
#   inflating: src/T2399.png
#   inflating: src/T24.png
#   inflating: src/T240.png
#   inflating: src/T2400.png
#   inflating: src/T2401.png
#   inflating: src/T2402.png
#   inflating: src/T2403.png
#   inflating: src/T2404.png
#   inflating: src/T2405.png
#   inflating: src/T2406.png
#   inflating: src/T2407.png
#   inflating: src/T2408.png
#   inflating: src/T2409.png
#   inflating: src/T241.png
#   inflating: src/T2410.png
#   inflating: src/T2411.png
#   inflating: src/T2412.png
#   inflating: src/T2413.png
#   inflating: src/T2414.png
#   inflating: src/T2415.png
#   inflating: src/T2416.png
#   inflating: src/T2417.png
#   inflating: src/T2418.png
#   inflating: src/T2419.png
#   inflating: src/T242.png
#   inflating: src/T2420.png
#   inflating: src/T2421.png
#   inflating: src/T2422.png
#   inflating: src/T2423.png
#   inflating: src/T2424.png
#   inflating: src/T2425.png
#   inflating: src/T2426.png
#   inflating: src/T2427.png
#   inflating: src/T2428.png
#   inflating: src/T2429.png
#   inflating: src/T243.png
#   inflating: src/T2430.png
#   inflating: src/T2431.png
#   inflating: src/T2432.png
#   inflating: src/T2433.png
#   inflating: src/T2434.png
#   inflating: src/T2435.png
#   inflating: src/T2436.png
#   inflating: src/T2437.png
#   inflating: src/T2438.png
#   inflating: src/T2439.png
#   inflating: src/T244.png
#   inflating: src/T2440.png
#   inflating: src/T2441.png
#   inflating: src/T2442.png
#   inflating: src/T2443.png
#   inflating: src/T2444.png
#   inflating: src/T2445.png
#   inflating: src/T2446.png
#   inflating: src/T2447.png
#   inflating: src/T2448.png
#   inflating: src/T2449.png
#   inflating: src/T245.png
#   inflating: src/T2450.png
#   inflating: src/T2451.png
#   inflating: src/T2452.png
#   inflating: src/T2453.png
#   inflating: src/T2454.png
#   inflating: src/T2455.png
#   inflating: src/T2456.png
#   inflating: src/T2457.png
#   inflating: src/T2458.png
#   inflating: src/T2459.png
#   inflating: src/T246.png
#   inflating: src/T2460.png
#   inflating: src/T2461.png
#   inflating: src/T2462.png
#   inflating: src/T2463.png
#   inflating: src/T2464.png
#   inflating: src/T2465.png
#   inflating: src/T2466.png
#   inflating: src/T2467.png
#   inflating: src/T2468.png
#   inflating: src/T2469.png
#   inflating: src/T247.png
#   inflating: src/T2470.png
#   inflating: src/T2471.png
#   inflating: src/T2472.png
#   inflating: src/T2473.png
#   inflating: src/T2474.png
#   inflating: src/T2475.png
#   inflating: src/T2476.png
#   inflating: src/T2477.png
#   inflating: src/T2478.png
#   inflating: src/T2479.png
#   inflating: src/T248.png
#   inflating: src/T2480.png
#   inflating: src/T2481.png
#   inflating: src/T2482.png
#   inflating: src/T2483.png
#   inflating: src/T2484.png
#   inflating: src/T2485.png
#   inflating: src/T2486.png
#   inflating: src/T2487.png
#   inflating: src/T2488.png
#   inflating: src/T2489.png
#   inflating: src/T249.png
#   inflating: src/T2490.png
#   inflating: src/T2491.png
#   inflating: src/T2492.png
#   inflating: src/T2493.png
#   inflating: src/T2494.png
#   inflating: src/T2495.png
#   inflating: src/T2496.png
#   inflating: src/T2497.png
#   inflating: src/T2498.png
#   inflating: src/T2499.png
#   inflating: src/T25.png
#   inflating: src/T250.png
#   inflating: src/T2500.png
#   inflating: src/T2501.png
#   inflating: src/T2502.png
#   inflating: src/T2503.png
#   inflating: src/T2504.png
#   inflating: src/T2505.png
#   inflating: src/T2506.png
#   inflating: src/T2507.png
#   inflating: src/T2508.png
#   inflating: src/T2509.png
#   inflating: src/T251.png
#   inflating: src/T2510.png
#   inflating: src/T2511.png
#   inflating: src/T2512.png
#   inflating: src/T2513.png
#   inflating: src/T2514.png
#   inflating: src/T2515.png
#   inflating: src/T2516.png
#   inflating: src/T2517.png
#   inflating: src/T2518.png
#   inflating: src/T2519.png
#   inflating: src/T252.png
#   inflating: src/T2520.png
#   inflating: src/T2521.png
#   inflating: src/T2522.png
#   inflating: src/T2523.png
#   inflating: src/T2524.png
#   inflating: src/T2525.png
#   inflating: src/T2526.png
#   inflating: src/T2527.png
#   inflating: src/T2528.png
#   inflating: src/T2529.png
#   inflating: src/T253.png
#   inflating: src/T2530.png
#   inflating: src/T2531.png
#   inflating: src/T2532.png
#   inflating: src/T2533.png
#   inflating: src/T2534.png
#   inflating: src/T2535.png
#   inflating: src/T2536.png
#   inflating: src/T2537.png
#   inflating: src/T2538.png
#   inflating: src/T2539.png
#   inflating: src/T254.png
#   inflating: src/T2540.png
#   inflating: src/T2541.png
#   inflating: src/T2542.png
#   inflating: src/T2543.png
#   inflating: src/T2544.png
#   inflating: src/T2545.png
#   inflating: src/T2546.png
#   inflating: src/T2547.png
#   inflating: src/T2548.png
#   inflating: src/T2549.png
#   inflating: src/T255.png
#   inflating: src/T2550.png
#   inflating: src/T2551.png
#   inflating: src/T2552.png
#   inflating: src/T2553.png
#   inflating: src/T2554.png
#   inflating: src/T2555.png
#   inflating: src/T2556.png
#   inflating: src/T2557.png
#   inflating: src/T2558.png
#   inflating: src/T2559.png
#   inflating: src/T256.png
#   inflating: src/T2560.png
#   inflating: src/T2561.png
#   inflating: src/T2562.png
#   inflating: src/T2563.png
#   inflating: src/T2564.png
#   inflating: src/T2565.png
#   inflating: src/T2566.png
#   inflating: src/T2567.png
#   inflating: src/T2568.png
#   inflating: src/T2569.png
#   inflating: src/T257.png
#   inflating: src/T2570.png
#   inflating: src/T2571.png
#   inflating: src/T2572.png
#   inflating: src/T2573.png
#   inflating: src/T2574.png
#   inflating: src/T2575.png
#   inflating: src/T2576.png
#   inflating: src/T2577.png
#   inflating: src/T2578.png
#   inflating: src/T2579.png
#   inflating: src/T258.png
#   inflating: src/T2580.png
#   inflating: src/T2581.png
#   inflating: src/T2582.png
#   inflating: src/T2583.png
#   inflating: src/T2584.png
#   inflating: src/T2585.png
#   inflating: src/T2586.png
#   inflating: src/T2587.png
#   inflating: src/T2588.png
#   inflating: src/T2589.png
#   inflating: src/T259.png
#   inflating: src/T2590.png
#   inflating: src/T2591.png
#   inflating: src/T2592.png
#   inflating: src/T2593.png
#   inflating: src/T2594.png
#   inflating: src/T2595.png
#   inflating: src/T2596.png
#   inflating: src/T2597.png
#   inflating: src/T2598.png
#   inflating: src/T2599.png
#   inflating: src/T26.png
#   inflating: src/T260.png
#   inflating: src/T2600.png
#   inflating: src/T2601.png
#   inflating: src/T2602.png
#   inflating: src/T2603.png
#   inflating: src/T2604.png
#   inflating: src/T2605.png
#   inflating: src/T2606.png
#   inflating: src/T2607.png
#   inflating: src/T2608.png
#   inflating: src/T2609.png
#   inflating: src/T261.png
#   inflating: src/T2610.png
#   inflating: src/T2611.png
#   inflating: src/T2612.png
#   inflating: src/T2613.png
#   inflating: src/T2614.png
#   inflating: src/T2615.png
#   inflating: src/T2616.png
#   inflating: src/T2617.png
#   inflating: src/T2618.png
#   inflating: src/T2619.png
#   inflating: src/T262.png
#   inflating: src/T2620.png
#   inflating: src/T2621.png
#   inflating: src/T2622.png
#   inflating: src/T2623.png
#   inflating: src/T2624.png
#   inflating: src/T2625.png
#   inflating: src/T2626.png
#   inflating: src/T2627.png
#   inflating: src/T2628.png
#   inflating: src/T2629.png
#   inflating: src/T263.png
#   inflating: src/T2630.png
#   inflating: src/T2631.png
#   inflating: src/T2632.png
#   inflating: src/T2633.png
#   inflating: src/T2634.png
#   inflating: src/T2635.png
#   inflating: src/T2636.png
#   inflating: src/T2637.png
#   inflating: src/T2638.png
#   inflating: src/T2639.png
#   inflating: src/T264.png
#   inflating: src/T2640.png
#   inflating: src/T2641.png
#   inflating: src/T2642.png
#   inflating: src/T2643.png
#   inflating: src/T2644.png
#   inflating: src/T2645.png
#   inflating: src/T2646.png
#   inflating: src/T2647.png
#   inflating: src/T2648.png
#   inflating: src/T2649.png
#   inflating: src/T265.png
#   inflating: src/T2650.png
#   inflating: src/T2651.png
#   inflating: src/T2652.png
#   inflating: src/T2653.png
#   inflating: src/T2654.png
#   inflating: src/T2655.png
#   inflating: src/T2656.png
#   inflating: src/T2657.png
#   inflating: src/T2658.png
#   inflating: src/T2659.png
#   inflating: src/T266.png
#   inflating: src/T2660.png
#   inflating: src/T2661.png
#   inflating: src/T2662.png
#   inflating: src/T2663.png
#   inflating: src/T2664.png
#   inflating: src/T2665.png
#   inflating: src/T2666.png
#   inflating: src/T2667.png
#   inflating: src/T2668.png
#   inflating: src/T2669.png
#   inflating: src/T267.png
#   inflating: src/T2670.png
#   inflating: src/T2671.png
#   inflating: src/T2672.png
#   inflating: src/T2673.png
#   inflating: src/T2674.png
#   inflating: src/T2675.png
#   inflating: src/T2676.png
#   inflating: src/T2677.png
#   inflating: src/T2678.png
#   inflating: src/T2679.png
#   inflating: src/T268.png
#   inflating: src/T2680.png
#   inflating: src/T2681.png
#   inflating: src/T2682.png
#   inflating: src/T2683.png
#   inflating: src/T2684.png
#   inflating: src/T2685.png
#   inflating: src/T2686.png
#   inflating: src/T2687.png
#   inflating: src/T2688.png
#   inflating: src/T2689.png
#   inflating: src/T269.png
#   inflating: src/T2690.png
#   inflating: src/T2691.png
#   inflating: src/T2692.png
#   inflating: src/T2693.png
#   inflating: src/T2694.png
#   inflating: src/T2695.png
#   inflating: src/T2696.png
#   inflating: src/T2697.png
#   inflating: src/T2698.png
#   inflating: src/T2699.png
#   inflating: src/T27.png
#   inflating: src/T270.png
#   inflating: src/T2700.png
#   inflating: src/T2701.png
#   inflating: src/T2702.png
#   inflating: src/T2703.png
#   inflating: src/T2704.png
#   inflating: src/T2705.png
#   inflating: src/T2706.png
#   inflating: src/T2707.png
#   inflating: src/T2708.png
#   inflating: src/T2709.png
#   inflating: src/T271.png
#   inflating: src/T2710.png
#   inflating: src/T2711.png
#   inflating: src/T2712.png
#   inflating: src/T2713.png
#   inflating: src/T2714.png
#   inflating: src/T2715.png
#   inflating: src/T2716.png
#   inflating: src/T2717.png
#   inflating: src/T2718.png
#   inflating: src/T2719.png
#   inflating: src/T272.png
#   inflating: src/T2720.png
#   inflating: src/T2721.png
#   inflating: src/T2722.png
#   inflating: src/T2723.png
#   inflating: src/T2724.png
#   inflating: src/T2725.png
#   inflating: src/T2726.png
#   inflating: src/T2727.png
#   inflating: src/T2728.png
#   inflating: src/T2729.png
#   inflating: src/T273.png
#   inflating: src/T2730.png
#   inflating: src/T2731.png
#   inflating: src/T2732.png
#   inflating: src/T2733.png
#   inflating: src/T2734.png
#   inflating: src/T2735.png
#   inflating: src/T2736.png
#   inflating: src/T2737.png
#   inflating: src/T2738.png
#   inflating: src/T2739.png
#   inflating: src/T274.png
#   inflating: src/T2740.png
#   inflating: src/T2741.png
#   inflating: src/T2742.png
#   inflating: src/T2743.png
#   inflating: src/T2744.png
#   inflating: src/T2745.png
#   inflating: src/T2746.png
#   inflating: src/T2747.png
#   inflating: src/T2748.png
#   inflating: src/T2749.png
#   inflating: src/T275.png
#   inflating: src/T2750.png
#   inflating: src/T2751.png
#   inflating: src/T2752.png
#   inflating: src/T2753.png
#   inflating: src/T2754.png
#   inflating: src/T2755.png
#   inflating: src/T2756.png
#   inflating: src/T2757.png
#   inflating: src/T2758.png
#   inflating: src/T2759.png
#   inflating: src/T276.png
#   inflating: src/T2760.png
#   inflating: src/T2761.png
#   inflating: src/T2762.png
#   inflating: src/T2763.png
#   inflating: src/T2764.png
#   inflating: src/T2765.png
#   inflating: src/T2766.png
#   inflating: src/T2767.png
#   inflating: src/T2768.png
#   inflating: src/T2769.png
#   inflating: src/T277.png
#   inflating: src/T2770.png
#   inflating: src/T2771.png
#   inflating: src/T2772.png
#   inflating: src/T2773.png
#   inflating: src/T2774.png
#   inflating: src/T2775.png
#   inflating: src/T2776.png
#   inflating: src/T2777.png
#   inflating: src/T2778.png
#   inflating: src/T2779.png
#   inflating: src/T278.png
#   inflating: src/T2780.png
#   inflating: src/T2781.png
#   inflating: src/T2782.png
#   inflating: src/T2783.png
#   inflating: src/T2784.png
#   inflating: src/T2785.png
#   inflating: src/T2786.png
#   inflating: src/T2787.png
#   inflating: src/T2788.png
#   inflating: src/T2789.png
#   inflating: src/T279.png
#   inflating: src/T2790.png
#   inflating: src/T2791.png
#   inflating: src/T2792.png
#   inflating: src/T2793.png
#   inflating: src/T2794.png
#   inflating: src/T2795.png
#   inflating: src/T2796.png
#   inflating: src/T2797.png
#   inflating: src/T2798.png
#   inflating: src/T2799.png
#   inflating: src/T28.png
#   inflating: src/T280.png
#   inflating: src/T2800.png
#   inflating: src/T2801.png
#   inflating: src/T2802.png
#   inflating: src/T2803.png
#   inflating: src/T2804.png
#   inflating: src/T2805.png
#   inflating: src/T2806.png
#   inflating: src/T2807.png
#   inflating: src/T2808.png
#   inflating: src/T2809.png
#   inflating: src/T281.png
#   inflating: src/T2810.png
#   inflating: src/T2811.png
#   inflating: src/T2812.png
#   inflating: src/T2813.png
#   inflating: src/T2814.png
#   inflating: src/T2815.png
#   inflating: src/T2816.png
#   inflating: src/T2817.png
#   inflating: src/T2818.png
#   inflating: src/T2819.png
#   inflating: src/T282.png
#   inflating: src/T2820.png
#   inflating: src/T2821.png
#   inflating: src/T2822.png
#   inflating: src/T2823.png
#   inflating: src/T2824.png
#   inflating: src/T2825.png
#   inflating: src/T2826.png
#   inflating: src/T2827.png
#   inflating: src/T2828.png
#   inflating: src/T2829.png
#   inflating: src/T283.png
#   inflating: src/T2830.png
#   inflating: src/T2831.png
#   inflating: src/T2832.png
#   inflating: src/T2833.png
#   inflating: src/T2834.png
#   inflating: src/T2835.png
#   inflating: src/T2836.png
#   inflating: src/T2837.png
#   inflating: src/T2838.png
#   inflating: src/T2839.png
#   inflating: src/T284.png
#   inflating: src/T2840.png
#   inflating: src/T2841.png
#   inflating: src/T2842.png
#   inflating: src/T2843.png
#   inflating: src/T2844.png
#   inflating: src/T2845.png
#   inflating: src/T2846.png
#   inflating: src/T2847.png
#   inflating: src/T2848.png
#   inflating: src/T2849.png
#   inflating: src/T285.png
#   inflating: src/T2850.png
#   inflating: src/T2851.png
#   inflating: src/T2852.png
#   inflating: src/T2853.png
#   inflating: src/T2854.png
#   inflating: src/T2855.png
#   inflating: src/T2856.png
#   inflating: src/T2857.png
#   inflating: src/T2858.png
#   inflating: src/T2859.png
#   inflating: src/T286.png
#   inflating: src/T2860.png
#   inflating: src/T2861.png
#   inflating: src/T2862.png
#   inflating: src/T2863.png
#   inflating: src/T2864.png
#   inflating: src/T2865.png
#   inflating: src/T2866.png
#   inflating: src/T2867.png
#   inflating: src/T2868.png
#   inflating: src/T2869.png
#   inflating: src/T287.png
#   inflating: src/T2870.png
#   inflating: src/T2871.png
#   inflating: src/T2872.png
#   inflating: src/T2873.png
#   inflating: src/T2874.png
#   inflating: src/T2875.png
#   inflating: src/T2876.png
#   inflating: src/T2877.png
#   inflating: src/T2878.png
#   inflating: src/T2879.png
#   inflating: src/T288.png
#   inflating: src/T2880.png
#   inflating: src/T2881.png
#   inflating: src/T2882.png
#   inflating: src/T2883.png
#   inflating: src/T2884.png
#   inflating: src/T2885.png
#   inflating: src/T2886.png
#   inflating: src/T2887.png
#   inflating: src/T2888.png
#   inflating: src/T2889.png
#   inflating: src/T289.png
#   inflating: src/T2890.png
#   inflating: src/T2891.png
#   inflating: src/T2892.png
#   inflating: src/T2893.png
#   inflating: src/T2894.png
#   inflating: src/T2895.png
#   inflating: src/T2896.png
#   inflating: src/T2897.png
#   inflating: src/T2898.png
#   inflating: src/T2899.png
#   inflating: src/T29.png
#   inflating: src/T290.png
#   inflating: src/T2900.png
#   inflating: src/T2901.png
#   inflating: src/T2902.png
#   inflating: src/T2903.png
#   inflating: src/T2904.png
#   inflating: src/T2905.png
#   inflating: src/T2906.png
#   inflating: src/T2907.png
#   inflating: src/T2908.png
#   inflating: src/T2909.png
#   inflating: src/T291.png
#   inflating: src/T2910.png
#   inflating: src/T2911.png
#   inflating: src/T2912.png
#   inflating: src/T2913.png
#   inflating: src/T2914.png
#   inflating: src/T2915.png
#   inflating: src/T2916.png
#   inflating: src/T2917.png
#   inflating: src/T2918.png
#   inflating: src/T2919.png
#   inflating: src/T292.png
#   inflating: src/T2920.png
#   inflating: src/T2921.png
#   inflating: src/T2922.png
#   inflating: src/T2923.png
#   inflating: src/T2924.png
#   inflating: src/T2925.png
#   inflating: src/T2926.png
#   inflating: src/T2927.png
#   inflating: src/T2928.png
#   inflating: src/T2929.png
#   inflating: src/T293.png
#   inflating: src/T2930.png
#   inflating: src/T2931.png
#   inflating: src/T2932.png
#   inflating: src/T2933.png
#   inflating: src/T2934.png
#   inflating: src/T2935.png
#   inflating: src/T2936.png
#   inflating: src/T2937.png
#   inflating: src/T2938.png
#   inflating: src/T2939.png
#   inflating: src/T294.png
#   inflating: src/T2940.png
#   inflating: src/T2941.png
#   inflating: src/T2942.png
#   inflating: src/T2943.png
#   inflating: src/T2944.png
#   inflating: src/T2945.png
#   inflating: src/T2946.png
#   inflating: src/T2947.png
#   inflating: src/T2948.png
#   inflating: src/T2949.png
#   inflating: src/T295.png
#   inflating: src/T2950.png
#   inflating: src/T2951.png
#   inflating: src/T2952.png
#   inflating: src/T2953.png
#   inflating: src/T2954.png
#   inflating: src/T2955.png
#   inflating: src/T2956.png
#   inflating: src/T2957.png
#   inflating: src/T2958.png
#   inflating: src/T2959.png
#   inflating: src/T296.png
#   inflating: src/T2960.png
#   inflating: src/T2961.png
#   inflating: src/T2962.png
#   inflating: src/T2963.png
#   inflating: src/T2964.png
#   inflating: src/T2965.png
#   inflating: src/T2966.png
#   inflating: src/T2967.png
#   inflating: src/T2968.png
#   inflating: src/T2969.png
#   inflating: src/T297.png
#   inflating: src/T2970.png
#   inflating: src/T2971.png
#   inflating: src/T2972.png
#   inflating: src/T2973.png
#   inflating: src/T2974.png
#   inflating: src/T2975.png
#   inflating: src/T2976.png
#   inflating: src/T2977.png
#   inflating: src/T2978.png
#   inflating: src/T2979.png
#   inflating: src/T298.png
#   inflating: src/T2980.png
#   inflating: src/T2981.png
#   inflating: src/T2982.png
#   inflating: src/T2983.png
#   inflating: src/T2984.png
#   inflating: src/T2985.png
#   inflating: src/T2986.png
#   inflating: src/T2987.png
#   inflating: src/T2988.png
#   inflating: src/T2989.png
#   inflating: src/T299.png
#   inflating: src/T2990.png
#   inflating: src/T2991.png
#   inflating: src/T2992.png
#   inflating: src/T2993.png
#   inflating: src/T2994.png
#   inflating: src/T2995.png
#   inflating: src/T2996.png
#   inflating: src/T2997.png
#   inflating: src/T2998.png
#   inflating: src/T2999.png
#   inflating: src/T3.png
#   inflating: src/T30.png
#   inflating: src/T300.png
#   inflating: src/T3000.png
#   inflating: src/T3001.png
#   inflating: src/T3002.png
#   inflating: src/T3003.png
#   inflating: src/T3004.png
#   inflating: src/T3005.png
#   inflating: src/T3006.png
#   inflating: src/T3007.png
#   inflating: src/T3008.png
#   inflating: src/T3009.png
#   inflating: src/T301.png
#   inflating: src/T3010.png
#   inflating: src/T3011.png
#   inflating: src/T3012.png
#   inflating: src/T3013.png
#   inflating: src/T3014.png
#   inflating: src/T3015.png
#   inflating: src/T3016.png
#   inflating: src/T3017.png
#   inflating: src/T3018.png
#   inflating: src/T3019.png
# ...
#   inflating: src/W634.png
#   inflating: src/W635.png
#   inflating: src/W636.png
#   inflating: src/W637.png
#   inflating: src/W638.png
#   inflating: src/W639.png
#   inflating: src/W64.png
#   inflating: src/W640.png
#   inflating: src/W641.png
#   inflating: src/W642.png
#   inflating: src/W643.png
#   inflating: src/W644.png
#   inflating: src/W645.png
#   inflating: src/W646.png
#   inflating: src/W647.png
#   inflating: src/W648.png
#   inflating: src/W649.png
#   inflating: src/W65.png
#   inflating: src/W650.png
#   inflating: src/W651.png
#   inflating: src/W652.png
#   inflating: src/W653.png
#   inflating: src/W654.png
#   inflating: src/W655.png
#   inflating: src/W656.png
#   inflating: src/W657.png
#   inflating: src/W658.png
#   inflating: src/W659.png
#   inflating: src/W66.png
#   inflating: src/W660.png
#   inflating: src/W661.png
#   inflating: src/W662.png
#   inflating: src/W663.png
#   inflating: src/W664.png
#   inflating: src/W665.png
#   inflating: src/W666.png
#   inflating: src/W667.png
#   inflating: src/W668.png
#   inflating: src/W669.png
#   inflating: src/W67.png
#   inflating: src/W670.png
#   inflating: src/W671.png
#   inflating: src/W672.png
#   inflating: src/W673.png
#   inflating: src/W674.png
#   inflating: src/W675.png
#   inflating: src/W676.png
#   inflating: src/W677.png
#   inflating: src/W678.png
#   inflating: src/W679.png
#   inflating: src/W68.png
#   inflating: src/W680.png
#   inflating: src/W681.png
#   inflating: src/W682.png
#   inflating: src/W683.png
#   inflating: src/W684.png
#   inflating: src/W685.png
#   inflating: src/W686.png
#   inflating: src/W687.png
#   inflating: src/W688.png
#   inflating: src/W689.png
#   inflating: src/W69.png
#   inflating: src/W690.png
#   inflating: src/W691.png
#   inflating: src/W692.png
#   inflating: src/W693.png
#   inflating: src/W694.png
#   inflating: src/W695.png
#   inflating: src/W696.png
#   inflating: src/W697.png
#   inflating: src/W698.png
#   inflating: src/W699.png
#   inflating: src/W7.png
#   inflating: src/W70.png
#   inflating: src/W700.png
#   inflating: src/W701.png
#   inflating: src/W702.png
#   inflating: src/W703.png
#   inflating: src/W704.png
#   inflating: src/W705.png
#   inflating: src/W706.png
#   inflating: src/W707.png
#   inflating: src/W708.png
#   inflating: src/W709.png
#   inflating: src/W71.png
#   inflating: src/W710.png
#   inflating: src/W711.png
#   inflating: src/W712.png
#   inflating: src/W713.png
#   inflating: src/W714.png
#   inflating: src/W715.png
#   inflating: src/W716.png
#   inflating: src/W717.png
#   inflating: src/W718.png
#   inflating: src/W719.png
#   inflating: src/W72.png
#   inflating: src/W720.png
#   inflating: src/W721.png
#   inflating: src/W722.png
#   inflating: src/W723.png
#   inflating: src/W724.png
#   inflating: src/W725.png
#   inflating: src/W726.png
#   inflating: src/W727.png
#   inflating: src/W728.png
#   inflating: src/W729.png
#   inflating: src/W73.png
#   inflating: src/W730.png
#   inflating: src/W731.png
#   inflating: src/W732.png
#   inflating: src/W733.png
#   inflating: src/W734.png
#   inflating: src/W735.png
#   inflating: src/W736.png
#   inflating: src/W737.png
#   inflating: src/W738.png
#   inflating: src/W739.png
#   inflating: src/W74.png
#   inflating: src/W740.png
#   inflating: src/W741.png
#   inflating: src/W742.png
#   inflating: src/W743.png
#   inflating: src/W744.png
#   inflating: src/W745.png
#   inflating: src/W746.png
#   inflating: src/W747.png
#   inflating: src/W748.png
#   inflating: src/W749.png
#   inflating: src/W75.png
#   inflating: src/W750.png
#   inflating: src/W751.png
#   inflating: src/W752.png
#   inflating: src/W753.png
#   inflating: src/W754.png
#   inflating: src/W755.png
#   inflating: src/W756.png
#   inflating: src/W757.png
#   inflating: src/W758.png
#   inflating: src/W759.png
#   inflating: src/W76.png
#   inflating: src/W760.png
#   inflating: src/W761.png
#   inflating: src/W762.png
#   inflating: src/W763.png
#   inflating: src/W764.png
#   inflating: src/W765.png
#   inflating: src/W766.png
#   inflating: src/W767.png
#   inflating: src/W768.png
#   inflating: src/W769.png
#   inflating: src/W77.png
#   inflating: src/W770.png
#   inflating: src/W771.png
#   inflating: src/W772.png
#   inflating: src/W773.png
#   inflating: src/W774.png
#   inflating: src/W775.png
#   inflating: src/W776.png
#   inflating: src/W777.png
#   inflating: src/W778.png
#   inflating: src/W779.png
#   inflating: src/W78.png
#   inflating: src/W780.png
#   inflating: src/W781.png
#   inflating: src/W782.png
#   inflating: src/W783.png
#   inflating: src/W784.png
#   inflating: src/W785.png
#   inflating: src/W786.png
#   inflating: src/W787.png
#   inflating: src/W788.png
#   inflating: src/W789.png
#   inflating: src/W79.png
#   inflating: src/W790.png
#   inflating: src/W791.png
#   inflating: src/W792.png
#   inflating: src/W793.png
#   inflating: src/W794.png
#   inflating: src/W795.png
#   inflating: src/W796.png
#   inflating: src/W797.png
#   inflating: src/W798.png
#   inflating: src/W799.png
#   inflating: src/W8.png
#   inflating: src/W80.png
#   inflating: src/W800.png
#   inflating: src/W801.png
#   inflating: src/W802.png
#   inflating: src/W803.png
#   inflating: src/W804.png
#   inflating: src/W805.png
#   inflating: src/W806.png
#   inflating: src/W807.png
#   inflating: src/W808.png
#   inflating: src/W809.png
#   inflating: src/W81.png
#   inflating: src/W810.png
#   inflating: src/W811.png
#   inflating: src/W812.png
#   inflating: src/W813.png
#   inflating: src/W814.png
#   inflating: src/W815.png
#   inflating: src/W816.png
#   inflating: src/W817.png
#   inflating: src/W818.png
#   inflating: src/W819.png
#   inflating: src/W82.png
#   inflating: src/W820.png
#   inflating: src/W821.png
#   inflating: src/W822.png
#   inflating: src/W823.png
#   inflating: src/W824.png
#   inflating: src/W825.png
#   inflating: src/W826.png
#   inflating: src/W827.png
#   inflating: src/W828.png
#   inflating: src/W829.png
#   inflating: src/W83.png
#   inflating: src/W830.png
#   inflating: src/W831.png
#   inflating: src/W832.png
#   inflating: src/W833.png
#   inflating: src/W834.png
#   inflating: src/W835.png
#   inflating: src/W836.png
#   inflating: src/W837.png
#   inflating: src/W838.png
#   inflating: src/W839.png
#   inflating: src/W84.png
#   inflating: src/W840.png
#   inflating: src/W841.png
#   inflating: src/W842.png
#   inflating: src/W843.png
#   inflating: src/W844.png
#   inflating: src/W845.png
#   inflating: src/W846.png
#   inflating: src/W847.png
#   inflating: src/W848.png
#   inflating: src/W849.png
#   inflating: src/W85.png
#   inflating: src/W850.png
#   inflating: src/W851.png
#   inflating: src/W852.png
#   inflating: src/W853.png
#   inflating: src/W854.png
#   inflating: src/W855.png
#   inflating: src/W856.png
#   inflating: src/W857.png
#   inflating: src/W858.png
#   inflating: src/W859.png
#   inflating: src/W86.png
#   inflating: src/W860.png
#   inflating: src/W861.png
#   inflating: src/W862.png
#   inflating: src/W863.png
#   inflating: src/W864.png
#   inflating: src/W865.png
#   inflating: src/W866.png
#   inflating: src/W867.png
#   inflating: src/W868.png
#   inflating: src/W869.png
#   inflating: src/W87.png
#   inflating: src/W870.png
#   inflating: src/W871.png
#   inflating: src/W872.png
#   inflating: src/W873.png
#   inflating: src/W874.png
#   inflating: src/W875.png
#   inflating: src/W876.png
#   inflating: src/W877.png
#   inflating: src/W878.png
#   inflating: src/W879.png
#   inflating: src/W88.png
#   inflating: src/W880.png
#   inflating: src/W881.png
#   inflating: src/W882.png
#   inflating: src/W883.png
#   inflating: src/W884.png
#   inflating: src/W885.png
#   inflating: src/W886.png
#   inflating: src/W887.png
#   inflating: src/W888.png
#   inflating: src/W889.png
#   inflating: src/W89.png
#   inflating: src/W890.png
#   inflating: src/W891.png
#   inflating: src/W892.png
#   inflating: src/W893.png
#   inflating: src/W894.png
#   inflating: src/W895.png
#   inflating: src/W896.png
#   inflating: src/W897.png
#   inflating: src/W898.png
#   inflating: src/W899.png
#   inflating: src/W9.png
#   inflating: src/W90.png
#   inflating: src/W900.png
#   inflating: src/W901.png
#   inflating: src/W902.png
#   inflating: src/W903.png
#   inflating: src/W904.png
#   inflating: src/W905.png
#   inflating: src/W906.png
#   inflating: src/W907.png
#   inflating: src/W908.png
#   inflating: src/W909.png
#   inflating: src/W91.png
#   inflating: src/W910.png
#   inflating: src/W911.png
#   inflating: src/W912.png
#   inflating: src/W913.png
#   inflating: src/W914.png
#   inflating: src/W915.png
#   inflating: src/W916.png
#   inflating: src/W917.png
#   inflating: src/W918.png
#   inflating: src/W919.png
#   inflating: src/W92.png
#   inflating: src/W920.png
#   inflating: src/W921.png
#   inflating: src/W922.png
#   inflating: src/W923.png
#   inflating: src/W924.png
#   inflating: src/W925.png
#   inflating: src/W926.png
#   inflating: src/W927.png
#   inflating: src/W928.png
#   inflating: src/W929.png
#   inflating: src/W93.png
#   inflating: src/W930.png
#   inflating: src/W931.png
#   inflating: src/W932.png
#   inflating: src/W933.png
#   inflating: src/W934.png
#   inflating: src/W935.png
#   inflating: src/W936.png
#   inflating: src/W937.png
#   inflating: src/W938.png
#   inflating: src/W939.png
#   inflating: src/W94.png
#   inflating: src/W940.png
#   inflating: src/W941.png
#   inflating: src/W942.png
#   inflating: src/W943.png
#   inflating: src/W944.png
#   inflating: src/W945.png
#   inflating: src/W946.png
#   inflating: src/W947.png
#   inflating: src/W948.png
#   inflating: src/W949.png
#   inflating: src/W95.png
#   inflating: src/W950.png
#   inflating: src/W951.png
#   inflating: src/W952.png
#   inflating: src/W953.png
#   inflating: src/W954.png
#   inflating: src/W955.png
#   inflating: src/W956.png
#   inflating: src/W957.png
#   inflating: src/W958.png
#   inflating: src/W959.png
#   inflating: src/W96.png
#   inflating: src/W960.png
#   inflating: src/W961.png
#   inflating: src/W962.png
#   inflating: src/W963.png
#   inflating: src/W964.png
#   inflating: src/W965.png
#   inflating: src/W966.png
#   inflating: src/W967.png
#   inflating: src/W968.png
#   inflating: src/W969.png
#   inflating: src/W97.png
#   inflating: src/W970.png
#   inflating: src/W971.png
#   inflating: src/W972.png
#   inflating: src/W973.png
#   inflating: src/W974.png
#   inflating: src/W975.png
#   inflating: src/W976.png
#   inflating: src/W977.png
#   inflating: src/W978.png
#   inflating: src/W979.png
#   inflating: src/W98.png
#   inflating: src/W980.png
#   inflating: src/W981.png
#   inflating: src/W982.png
#   inflating: src/W983.png
#   inflating: src/W984.png
#   inflating: src/W985.png
#   inflating: src/W986.png
#   inflating: src/W987.png
#   inflating: src/W988.png
#   inflating: src/W989.png
#   inflating: src/W99.png
#   inflating: src/W990.png
#   inflating: src/W991.png
#   inflating: src/W992.png
#   inflating: src/W993.png
#   inflating: src/W994.png
#   inflating: src/W995.png
#   inflating: src/W996.png
#   inflating: src/W997.png
#   inflating: src/W998.png
#   inflating: src/W999.png
#   inflating: test/label/S008.png
#   inflating: test/label/T25.png
#   inflating: test/label/T37.png
#   inflating: test/label/T41.png
#   inflating: test/label/T44.png
#   inflating: test/label/TT0.png
#   inflating: test/label/W1299.png
#   inflating: test/label/W1315.png
#   inflating: test/src/S008.png
#   inflating: test/src/T25.png
#   inflating: test/src/T37.png
#   inflating: test/src/T41.png
#   inflating: test/src/T44.png
#   inflating: test/src/TT0.png
#   inflating: test/src/W1299.png
#   inflating: test/src/W1315.png

# %% [markdown]
# # 3- Create a function that converts the images paths into a dataframe(make sure that the images and their masks are matching)

# %%
def read_file (path_file):
  image_list=sorted(glob.glob(f'{path_file}/*.png'))
  return image_list


scr_image = read_file('/content/src')
label_image = read_file('/content/label')


def create_dataset(scr_img,mask_img):
  data=pd.DataFrame({'images':scr_img,'masks':mask_img})
  return data 


dataset = create_dataset(scr_image,label_image)
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 4- Convert the mask into one hot vector

# %%
NUM_CLASSES = 2


def read_image(x,y):
    
    x=tf.io.read_file(x)
    x=tf.image.decode_png(x,channels=3)
    x = tf.image.convert_image_dtype(x, tf.float32)
    x = tf.image.resize(x, [224, 224])
    x=tf.clip_by_value(x,clip_value_min=0,clip_value_max=1)


    y=tf.io.read_file(y)
    y=tf.image.decode_png(y,channels=1)
    y = tf.image.resize(y, [224, 224],
                        method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    
    y=tf.clip_by_value(y,clip_value_min=0,clip_value_max=1)
    y=tf.reshape(y,(224,224))
    y=tf.one_hot(y,depth=NUM_CLASSES)

    return x,y


def data_aug(x,y):
  
    
    seed=np.random.randint(low=0,high=100,size=1)
    
    tf.compat.v1.set_random_seed(seed)
    x = tf.image.random_flip_up_down(x,seed=seed[0])
    x = tf.image.random_flip_left_right(x,seed=seed[0])
    x = tf.image.random_brightness(x, max_delta=32.0 / 255.0)
    x = tf.image.random_saturation(x, lower=0.5, upper=1.5)
    x = tf.clip_by_value(x, 0.0, 1.0)
    
    
    y=tf.argmax(y,axis=-1)
    y=tf.reshape(y,shape=(224,224,1))
    y=tf.image.random_flip_up_down(y,seed=seed[0])
    y=tf.image.random_flip_left_right(y,seed=seed[0])
    y=tf.reshape(y,shape=(224,224))
    y=tf.one_hot(y,depth=NUM_CLASSES)



    return x,y

# %% [markdown]
# # 5- Split the dataset into train and test dateset (test dataset should be 10% of the total dataset)

# %%
# write your code below
(train,test)= model_selection.train_test_split(dataset,test_size=0.1,random_state=42)

# %%
test
# Out:
#                       images                     masks
# 1870  /content/src/T2627.png  /content/label/T2627.png
# 5922   /content/src/W901.png   /content/label/W901.png
# 1328  /content/src/T2139.png  /content/label/T2139.png
# 5082  /content/src/W1468.png  /content/label/W1468.png
# 3411  /content/src/T4013.png  /content/label/T4013.png
# ...                      ...                       ...
# 1022  /content/src/T1864.png  /content/label/T1864.png
# 3800  /content/src/T4364.png  /content/label/T4364.png
# 3932  /content/src/T4483.png  /content/label/T4483.png
# 4560     /content/src/W0.png     /content/label/W0.png
# 4515   /content/src/T959.png   /content/label/T959.png
#
# [603 rows x 2 columns]

# %% [markdown]
# # 6- Create data pipeline with data augmentation
#
# Notes:<br>
# 1. Read images using tensorflow.
# 2. Make sure the pixels values are scaled between (0-1).
# 3. Resize the images to (224,224).
# 4. Apply multiple image augmentation on the data(make sure that the image augmentation is reflected on its mask).
# 5. Make sure the augmentation image pixels are scaled between (0-1).

# %%
# write your code below
def dataset_creater(x,y,training=False):
  data=tf.data.Dataset.from_tensor_slices((x,y))

  data=data.shuffle(1028,reshuffle_each_iteration=True)

  data=data.map(read_image,num_parallel_calls=tf.data.AUTOTUNE)


  if training:
    data=data.map(data_aug,num_parallel_calls=tf.data.AUTOTUNE)

  data=data.batch(32)
  data=data.prefetch(tf.data.AUTOTUNE)

  return data

train_dataset=dataset_creater(train.images,train.masks,training=True)
test_dataset=dataset_creater(test.images,test.masks)
# Out:
# pass 1 error
# pass 12 error
# pass 13 error
# pass 1 error
# pass 12 error
# pass 13 error

# %% [markdown]
# # 7- Plot the images

# %%
# write your code below
n = 10
plt.figure(figsize=(20, 4))

for x,y in train_dataset.take(1):



    for i in range(n):
        ax=plt.subplot(2, n, i + 1)
        plt.title(f"{i}")
        plt.imshow(tf.squeeze(x[i]))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    

    
        bx=plt.subplot(2, n, n+i + 1)

    
        
        plt.imshow(tf.squeeze(tf.argmax(y[i],-1)))
        plt.gray()
        bx.get_xaxis().set_visible(False)
        bx.get_yaxis().set_visible(False)

        


plt.show()

# %% [markdown]
# # 8- Build Autoencoder model

# %% [markdown]
# ### Encoder

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self):
        super(Encoder,self).__init__()
        
        self.conv1,self.Bn1=self.block_encoder(16)

        self.conv2,self.Bn2=self.block_encoder(32,(2,2))
       
        self.conv3,self.Bn3=self.block_encoder(64)
        
        self.conv4,self.Bn4=self.block_encoder(128,(2,2))
         
        self.conv5,self.Bn5=self.block_encoder(256)
        



    def block_encoder(self,num_filters,strides_n=(1,1)):
      Conv=tf.keras.layers.Conv2D(filters=num_filters,kernel_size=(3,3),
                                    strides=strides_n,padding='same',use_bias=False)
      BN=tf.keras.layers.BatchNormalization()

      return Conv,BN
          
       
     
      

    def call(self,x):
        #block 1
        x=self.conv1(x)
        x=self.Bn1(x)
        x=tf.nn.leaky_relu(x)
        #block 2
        x=self.conv2(x)
        x=self.Bn2(x)
        x=tf.nn.leaky_relu(x)
        #block 3
        x=self.conv3(x)
        x=self.Bn3(x)
        x=tf.nn.leaky_relu(x)
        #block 4
        x=self.conv4(x)
        x=self.Bn4(x)
        x=tf.nn.leaky_relu(x)
        #block 5
        x=self.conv5(x)
        x=self.Bn5(x)
        x=tf.nn.leaky_relu(x)


        return x 

    def build_model(self,dim):
        x=tf.keras.layers.Input(shape=dim)
        return tf.keras.Model(inputs=[x],outputs=[self.call(x)])

encoder=Encoder()
encoder.build_model((224,224,3)).summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      432
#
#  batch_normalization (BatchN  (None, 224, 224, 16)     64
#  ormalization)
#
#  tf.nn.leaky_relu (TFOpLambd  (None, 224, 224, 16)     0
#  a)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4608
#
#  batch_normalization_1 (Batc  (None, 112, 112, 32)     128
#  hNormalization)
#
#  tf.nn.leaky_relu_1 (TFOpLam  (None, 112, 112, 32)     0
#  bda)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18432
#
#  batch_normalization_2 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  tf.nn.leaky_relu_2 (TFOpLam  (None, 112, 112, 64)     0
#  bda)
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 128)       73728
#
#  batch_normalization_3 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  tf.nn.leaky_relu_3 (TFOpLam  (None, 56, 56, 128)      0
#  bda)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       294912
#
#  batch_normalization_4 (Batc  (None, 56, 56, 256)      1024
#  hNormalization)
#
#  tf.nn.leaky_relu_4 (TFOpLam  (None, 56, 56, 256)      0
#  bda)
#
# =================================================================
# Total params: 394,096
# Trainable params: 393,104
# Non-trainable params: 992
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(encoder.build_model((224,224,3)),show_shapes=True)

# %% [markdown]
# ### Decoder

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self):
        super(Decoder,self).__init__()
        self.conv1,self.Bn1=self.block_decoder(256)
        self.conv2,self.Bn2=self.block_decoder(128,(2,2))
        self.conv3,self.Bn3=self.block_decoder(64)
        self.conv4,self.Bn4=self.block_decoder(32,(2,2))
        self.conv5,self.Bn5=self.block_decoder(16)
        self.Out,_=self.block_decoder(2)



    def block_decoder(self,num_filters,strides_n=(1,1)):
      Conv=tf.keras.layers.Conv2DTranspose(filters=num_filters,kernel_size=(3,3),
                                                  strides=strides_n,padding='same',use_bias=False)
      BN=tf.keras.layers.BatchNormalization()

      return Conv,BN
          
        


    def call(self,x):
        #block 1
        x=self.conv1(x)
        x=self.Bn1(x)
        x=tf.nn.leaky_relu(x)
        #block 2

        x=self.conv2(x)
        x=self.Bn2(x)
        x=tf.nn.leaky_relu(x)
        #block 3

        x=self.conv3(x)
        x=self.Bn3(x)
        x=tf.nn.leaky_relu(x)
        #block 4

        x=self.conv4(x)
        x=self.Bn4(x)
        x=tf.nn.leaky_relu(x)
        #block 5
        x=self.conv5(x)
        x=self.Bn5(x)
        x=tf.nn.leaky_relu(x)
        #block 6
        #notice we're using sigmoid to make sure the output value of the last Conv2DTranspose will be between 0,1
        

        output=self.Out(x)
        output=tf.nn.softmax(output)

        return output

    def build_model(self,dim):
        x=tf.keras.layers.Input(shape=dim)
        return tf.keras.Model(inputs=[x],outputs=[self.call(x)])

decoder=Decoder()
decoder.build_model((56,56,256)).summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 56, 56, 256)]     0
#
#  conv2d_transpose (Conv2DTra  (None, 56, 56, 256)      589824
#  nspose)
#
#  batch_normalization_5 (Batc  (None, 56, 56, 256)      1024
#  hNormalization)
#
#  tf.nn.leaky_relu_10 (TFOpLa  (None, 56, 56, 256)      0
#  mbda)
#
#  conv2d_transpose_1 (Conv2DT  (None, 112, 112, 128)    294912
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 112, 112, 128)    512
#  hNormalization)
#
#  tf.nn.leaky_relu_11 (TFOpLa  (None, 112, 112, 128)    0
#  mbda)
#
#  conv2d_transpose_2 (Conv2DT  (None, 112, 112, 64)     73728
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  tf.nn.leaky_relu_12 (TFOpLa  (None, 112, 112, 64)     0
#  mbda)
#
#  conv2d_transpose_3 (Conv2DT  (None, 224, 224, 32)     18432
#  ranspose)
#
#  batch_normalization_8 (Batc  (None, 224, 224, 32)     128
#  hNormalization)
#
#  tf.nn.leaky_relu_13 (TFOpLa  (None, 224, 224, 32)     0
#  mbda)
#
#  conv2d_transpose_4 (Conv2DT  (None, 224, 224, 16)     4608
#  ranspose)
#
#  batch_normalization_9 (Batc  (None, 224, 224, 16)     64
#  hNormalization)
#
#  tf.nn.leaky_relu_14 (TFOpLa  (None, 224, 224, 16)     0
#  mbda)
#
#  conv2d_transpose_5 (Conv2DT  (None, 224, 224, 2)      288
#  ranspose)
#
#  tf.nn.softmax (TFOpLambda)  (None, 224, 224, 2)       0
#
# =================================================================
# Total params: 983,776
# Trainable params: 982,784
# Non-trainable params: 992
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(decoder.build_model((56,56,256)),show_shapes=True)

# %% [markdown]
# ### Model

# %%
# write your code below
class Autoencoder(tf.keras.Model):
    def __init__(self):
        super(Autoencoder,self).__init__()
        #initialize the encoder 
        self.encoder=Encoder()
        #initialize the decoder 
        self.decoder=Decoder()
    def call(self,x):
        #input the noisy image to the encoder 
        x=self.encoder(x)
        #input the ouput of the encoder to the decoder
        x=self.decoder(x)

        #return the ouput of the decoder 
        #the ouput of the decoder will be denoising image 

        return x

autoencoder=Autoencoder()
autoencoder.build(input_shape=(None,224,224,3))
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_1 (Encoder)         multiple                  394096
#
#  decoder_1 (Decoder)         multiple                  983776
#
# =================================================================
# Total params: 1,377,872
# Trainable params: 1,375,888
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.losses.CategoricalCrossentropy(),metrics=['acc'])
autoencoder.fit(train_dataset,
                epochs=10,
                validation_data=test_dataset)
# Out:
# Epoch 1/10
# 170/170 [==============================] - 63s 359ms/step - loss: 0.3210 - acc: 0.8652 - val_loss: 0.3526 - val_acc: 0.8557
# Epoch 2/10
# 170/170 [==============================] - 61s 359ms/step - loss: 0.3158 - acc: 0.8676 - val_loss: 0.3580 - val_acc: 0.8440
# Epoch 3/10
# 170/170 [==============================] - 62s 363ms/step - loss: 0.3080 - acc: 0.8704 - val_loss: 0.3155 - val_acc: 0.8662
# Epoch 4/10
# 170/170 [==============================] - 63s 368ms/step - loss: 0.3019 - acc: 0.8732 - val_loss: 0.2833 - val_acc: 0.8810
# Epoch 5/10
# 170/170 [==============================] - 62s 364ms/step - loss: 0.3011 - acc: 0.8745 - val_loss: 0.3223 - val_acc: 0.8635
# Epoch 6/10
# 170/170 [==============================] - 63s 370ms/step - loss: 0.2961 - acc: 0.8759 - val_loss: 0.2997 - val_acc: 0.8696
# Epoch 7/10
# 170/170 [==============================] - 62s 366ms/step - loss: 0.2874 - acc: 0.8791 - val_loss: 0.2822 - val_acc: 0.8792
# Epoch 8/10
# 170/170 [==============================] - 64s 376ms/step - loss: 0.2919 - acc: 0.8775 - val_loss: 0.3063 - val_acc: 0.8672
# Epoch 9/10
# 170/170 [==============================] - 64s 373ms/step - loss: 0.2830 - acc: 0.8814 - val_loss: 0.2717 - val_acc: 0.8877
# Epoch 10/10
# 170/170 [==============================] - 64s 377ms/step - loss: 0.2777 - acc: 0.8837 - val_loss: 0.3817 - val_acc: 0.8620

# %% [markdown]
# # 8- Plot the autoencoder model results

# %%
# plot the images
for x, y in test_dataset.take(1):
    pred=autoencoder(x,training=False)
    pred=tf.argmax(pred,axis=-1)
    n = 10
    plt.figure(figsize=(40, 20))
    for i in range(n):
        ax=plt.subplot(3, n, i + 1)
        plt.title(f"{i}")
        plt.imshow(tf.squeeze(x[i]))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        bx=plt.subplot(3, n, n+i + 1)
        plt.imshow(tf.squeeze(tf.argmax(y[i],axis=-1)))
        plt.gray()
        bx.get_xaxis().set_visible(False)
        bx.get_yaxis().set_visible(False)
        cx=plt.subplot(3, n, n+i+n + 1)
        plt.imshow(tf.squeeze(pred[i]))
        plt.gray()
        cx.get_xaxis().set_visible(False)
        cx.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # 9- Build UNet model
#
# Note: use sub-class to create the model.

# %% [markdown]
# ### Convolution Block

# %%
class ConvBlock(tf.keras.layers.Layer):
    
    def __init__(self,filters):
        super(ConvBlock,self).__init__()
        # add conv2d to the block with BN layer
        self.Conv_1=tf.keras.layers.Conv2D(filters=filters,kernel_size=(3,3),padding='same',use_bias=False)
        self.BN_1=tf.keras.layers.BatchNormalization()
        # add conv2d to the block with BN layer
        self.Conv_2=tf.keras.layers.Conv2D(filters=filters,kernel_size=(3,3),padding='same',use_bias=False)
        self.BN_2=tf.keras.layers.BatchNormalization()
    def call(self,x):
        x=self.Conv_1(x)
        x=self.BN_1(x)
        x=tf.nn.leaky_relu(x)

        x=self.Conv_2(x)
        x=self.BN_2(x)
        x=tf.nn.leaky_relu(x)

        return x

# %% [markdown]
# ### Encoder UNet

# %%
class EncoderBlock(tf.keras.layers.Layer):
    def __init__(self,filters):
        super(EncoderBlock,self).__init__()
       
        self.Conv_block=ConvBlock(filters)
  
        self.Max_pool=tf.keras.layers.MaxPooling2D()

    def call(self,x):
        x=self.Conv_block(x)
        p=self.Max_pool(x)

        return x,p

# %%
class DecoderBlock(tf.keras.layers.Layer):
    def __init__(self,filters):
        super(DecoderBlock,self).__init__()
        
        self.ConvTranspose=tf.keras.layers.Conv2DTranspose(filters,kernel_size=(2,2),strides=(2,2),padding='same')
        self.Conv_block=ConvBlock(filters)

    def call(self,input, skip_features):
      
        x=self.ConvTranspose(input)
        
        x=tf.keras.layers.concatenate([x,skip_features])
        x=self.Conv_block(x)
        return x

# %%
# write your code below
class UNet_Model(tf.keras.Model):
  def __init__(self,n_classes=NUM_CLASSES):
    super(UNet_Model,self).__init__()
   
    self.encoder_block_1=EncoderBlock(32)
    self.encoder_block_2=EncoderBlock(64)
    self.encoder_block_3=EncoderBlock(128)
    self.encoder_block_4=EncoderBlock(256)
    self.encoder_block_5=EncoderBlock(512)

    self.conv_block_6=ConvBlock(1028)

    self.decoder_block_7=DecoderBlock(512)
    self.decoder_block_8=DecoderBlock(256)
    self.decoder_block_9=DecoderBlock(128)
    self.decoder_block_10=DecoderBlock(64)
    self.decoder_block_11=DecoderBlock(32)


    self.out = tf.keras.layers.Conv2D(n_classes,kernel_size=(1,1))




  def call(self,x):
       
      s1,x=self.encoder_block_1(x)
      s2,x=self.encoder_block_2(x)
      s3,x=self.encoder_block_3(x)
      s4,x=self.encoder_block_4(x)
      s5,x=self.encoder_block_5(x)

      x=self.conv_block_6(x)
      x=self.decoder_block_7(x,s5)
      x=self.decoder_block_8(x,s4)
      x=self.decoder_block_9(x,s3)
      x=self.decoder_block_10(x,s2)
      x=self.decoder_block_11(x,s1)
      x=self.out(x)
      x=tf.nn.softmax(x)





      return x
  def build_model(self,dim=(256,256,3)):
    x=tf.keras.layers.Input(dim)
    return tf.keras.Model(inputs=[x],outputs=[self.call(x)])

uNet_Model=UNet_Model()
uNet_Model.build_model().summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  encoder_block_31 (EncoderBlock  ((None, 256, 256, 3  10336      ['input_8[0][0]']
#  )                              2),
#                                  (None, 128, 128, 3
#                                 2))
#
#  encoder_block_32 (EncoderBlock  ((None, 128, 128, 6  55808      ['encoder_block_31[0][1]']
#  )                              4),
#                                  (None, 64, 64, 64)
#                                 )
#
#  encoder_block_33 (EncoderBlock  ((None, 64, 64, 128  222208     ['encoder_block_32[0][1]']
#  )                              ),
#                                  (None, 32, 32, 128
#                                 ))
#
#  encoder_block_34 (EncoderBlock  ((None, 32, 32, 256  886784     ['encoder_block_33[0][1]']
#  )                              ),
#                                  (None, 16, 16, 256
#                                 ))
#
#  encoder_block_35 (EncoderBlock  ((None, 16, 16, 512  3543040    ['encoder_block_34[0][1]']
#  )                              ),
#                                  (None, 8, 8, 512))
#
#  conv_block_71 (ConvBlock)      (None, 8, 8, 1028)   14256304    ['encoder_block_35[0][1]']
#
#  decoder_block_30 (DecoderBlock  (None, 16, 16, 512)  9187840    ['conv_block_71[0][0]',
#  )                                                                'encoder_block_35[0][0]']
#
#  decoder_block_31 (DecoderBlock  (None, 32, 32, 256)  2296064    ['decoder_block_30[0][0]',
#  )                                                                'encoder_block_34[0][0]']
#
#  decoder_block_32 (DecoderBlock  (None, 64, 64, 128)  574592     ['decoder_block_31[0][0]',
#  )                                                                'encoder_block_33[0][0]']
#
#  decoder_block_33 (DecoderBlock  (None, 128, 128, 64  143936     ['decoder_block_32[0][0]',
#  )                              )                                 'encoder_block_32[0][0]']
#
#  decoder_block_34 (DecoderBlock  (None, 256, 256, 32  36128      ['decoder_block_33[0][0]',
#  )                              )                                 'encoder_block_31[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 256, 256, 2)  66          ['decoder_block_34[0][0]']
#
#  tf.nn.softmax_4 (TFOpLambda)   (None, 256, 256, 2)  0           ['conv2d_170[0][0]']
#
# ==================================================================================================
# Total params: 31,213,106
# Trainable params: 31,201,058
# Non-trainable params: 12,048
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(uNet_Model.build_model(),show_dtype=True)

# %%
uNet_Model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.losses.CategoricalCrossentropy(),metrics=['acc'])
uNet_Model.fit(train_dataset,
                epochs=10,
                validation_data=test_dataset)
# Out:
# Epoch 1/10
# 170/170 [==============================] - 122s 655ms/step - loss: 0.3876 - acc: 0.8366 - val_loss: 0.8150 - val_acc: 0.8019
# Epoch 2/10
# 170/170 [==============================] - 101s 591ms/step - loss: 0.3445 - acc: 0.8564 - val_loss: 0.4712 - val_acc: 0.8436
# Epoch 3/10
# 170/170 [==============================] - 100s 584ms/step - loss: 0.3262 - acc: 0.8646 - val_loss: 0.3369 - val_acc: 0.8658
# Epoch 4/10
# 170/170 [==============================] - 102s 600ms/step - loss: 0.3133 - acc: 0.8703 - val_loss: 0.3697 - val_acc: 0.8437
# Epoch 5/10
# 170/170 [==============================] - 102s 601ms/step - loss: 0.3052 - acc: 0.8732 - val_loss: 0.4964 - val_acc: 0.7417
# Epoch 6/10
# 170/170 [==============================] - 103s 602ms/step - loss: 0.2861 - acc: 0.8816 - val_loss: 0.3211 - val_acc: 0.8609
# Epoch 7/10
# 170/170 [==============================] - 103s 602ms/step - loss: 0.2804 - acc: 0.8834 - val_loss: 0.4124 - val_acc: 0.8560
# Epoch 8/10
# 170/170 [==============================] - 103s 603ms/step - loss: 0.2785 - acc: 0.8843 - val_loss: 0.3001 - val_acc: 0.8656
# Epoch 9/10
# 170/170 [==============================] - 103s 602ms/step - loss: 0.2631 - acc: 0.8905 - val_loss: 0.3311 - val_acc: 0.8624
# Epoch 10/10
# 170/170 [==============================] - 103s 603ms/step - loss: 0.2581 - acc: 0.8924 - val_loss: 0.2529 - val_acc: 0.8963

# %% [markdown]
# # 10- Plot the model results

# %%
# write your code below
# plot the images
for x, y in test_dataset.take(1):
    pred=uNet_Model(x,training=False)
    pred=tf.argmax(pred,axis=-1)
    n = 10
    plt.figure(figsize=(40, 20))
    for i in range(n):
        ax=plt.subplot(3, n, i + 1)
        plt.title(f"{i}")
        plt.imshow(tf.squeeze(x[i]))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        bx=plt.subplot(3, n, n+i + 1)
        plt.imshow(tf.squeeze(tf.argmax(y[i],axis=-1)))
        plt.gray()
        bx.get_xaxis().set_visible(False)
        bx.get_yaxis().set_visible(False)
        cx=plt.subplot(3, n, n+i+n + 1)
        plt.imshow(tf.squeeze(pred[i]))
        plt.gray()
        cx.get_xaxis().set_visible(False)
        cx.get_yaxis().set_visible(False)
plt.show()
